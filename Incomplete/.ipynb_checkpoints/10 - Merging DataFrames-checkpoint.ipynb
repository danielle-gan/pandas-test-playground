# %% [markdown]
# # Merging DataFrames

# %%
import pandas as pd

# %% [markdown]
# ## Our Dataset
# - Our datasets are spread across multiple files in this section. Each file has a `restaurant_` prefix.
# - The `customers.csv` file stores our restaurant's customers.
# - The `foods.csv` file stores our restaurant's menu items.
# - The `week_1_sales` and `week_2_sales` files store our orders.

# %%
customers = pd.read_csv("restaurant_customers.csv")
foods = pd.read_csv("restaurant_foods.csv")

week1 = pd.read_csv("restaurant_week_1_sales.csv")
week2 = pd.read_csv("restaurant_week_2_sales.csv")
customers
# Out:
#        ID First Name Last Name  Gender       Company  \
# 0       1     Joseph   Perkins    Male       Dynazzy
# 1       2   Jennifer   Alvarez  Female          DabZ
# 2       3      Roger     Black    Male       Tagfeed
# 3       4     Steven     Evans    Male          Fatz
# 4       5       Judy  Morrison  Female       Demivee
# ..    ...        ...       ...     ...           ...
# 995   996      Debra    Garcia  Female  Dazzlesphere
# 996   997    Douglas    Bishop    Male      Livepath
# 997   998      Frank  Franklin    Male    Brainverse
# 998   999    Jessica     Burns  Female    Babbleblab
# 999  1000      Brian   Daniels    Male         Tazzy
#
#                         Occupation
# 0    Community Outreach Specialist
# 1          Senior Quality Engineer
# 2                Account Executive
# 3                 Registered Nurse
# 4                  Legal Assistant
# ..                             ...
# 995            Structural Engineer
# 996                    Developer I
# 997             Nurse Practicioner
# 998              Financial Advisor
# 999     Physical Therapy Assistant
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## The pd.concat Function I
# - The `concat` function concatenates one **DataFrame** to the end of another.
# - The original index labels will be kept by default. Set `ignore_index` to True to generate a new index.
# - The `keys` parameter create a **MultiIndex** using the specified keys/labels.

# %%
pd.concat([week1, week2]) #this keeps the same index from the original DFs
pd.concat([week1, week2], ignore_index=True) #new index (default = False)
pd.concat([week1, week2], keys=["week 1", "week 2"]) #this is a multiindex DF
# Out:
#             Customer ID  Food ID
# week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
# ...                 ...      ...
# week 2 245          783       10
#        246          556       10
#        247          547        9
#        248          252        9
#        249          249        6
#
# [500 rows x 2 columns]

# %% [markdown]
# ## The pd.concat Function II
# - Pandas will concatenate the **DataFrames** along the row/index axis.
# - Pandas will include all columns that exist in either **DataFrame**. If there are no matching values, pandas will use `NaN` values.
# - We can pass the `axis` parameter an argument of `"columns"` to concatenate on the column axis.

# %%
DF1 = pd.DataFrame([1,2,3], columns=["A"])

# %%
DF2 = pd.DataFrame([4, 5, 6], columns=["B"])

# %%
pd.concat([DF1,DF2], axis=0)
pd.concat([DF1,DF2], axis="index") 

pd.concat([DF1,DF2], axis=1) #default axis = 0 (on the row axis on a 2D DF)
pd.concat([DF1,DF2], axis="columns")
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# get the data to be as similar to each other first before concatenating
# to make merging easier

# %% [markdown]
# ## Left Joins
# - The `merge` method joins two **DataFrames** together based on shared values in a column or an index.
# - A left join merges one **DataFrame** into another based on values in the first one.
# - The "left" **DataFrame** is the one we invoke the `merge` method on.
# - If the left **DataFrame's** value is not found in the right **DataFrame**, the row will hold `NaN` values.
# <img src="SQL_Joins.png" width="800" height="800"/>

# %%
week1.head() #the LEFT dataframe/the starting point :)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
foods.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
food_merge = week1.merge(foods, how="left", on="Food ID")
food_merge
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
master_table = food_merge.merge(customers, how="left", left_on="Customer ID", right_on="ID")

# %% [markdown]
# ## The left_on and right_on Parameters
# - The `left_on` and `right_on` parameters designate the column names from each **DataFrame** to use in the merge.

# %%
master_table = food_merge.merge(customers, how="left", left_on="Customer ID", right_on="ID")

# %%
master_table.drop("ID", axis="columns")
# Out:
#      Customer ID  Food ID   Food Item  Price First Name Last Name  Gender  \
# 0            537        9       Donut   0.99     Cheryl   Carroll  Female
# 1             97        4  Quesadilla   4.25     Amanda   Watkins  Female
# 2            658        1       Sushi   3.99    Patrick      Webb    Male
# 3            202        2     Burrito   9.99      Louis  Campbell    Male
# 4            155        9       Donut   0.99    Carolyn      Diaz  Female
# ..           ...      ...         ...    ...        ...       ...     ...
# 245          413        9       Donut   0.99      Diane    Bailey  Female
# 246          926        6       Pasta  13.99       Anne    Wagner  Female
# 247          134        3        Taco   2.99      Diana      Hall  Female
# 248          396        6       Pasta  13.99       Juan    Romero    Male
# 249          535       10       Drink   1.75      Nancy       Cox  Female
#
#        Company                     Occupation
# 0     Zoombeat               Registered Nurse
# 1          Ozu            Account Coordinator
# 2    Browsebug  Community Outreach Specialist
# 3    Rhynoodle     Account Representative III
# 4     Gigazoom     Database Administrator III
# ..         ...                            ...
# 245    Wikibox               Technical Writer
# 246      Skyba                Legal Assistant
# 247      Quinu              Financial Advisor
# 248    Zoonder             Analyst Programmer
# 249     Trudeo             Research Associate
#
# [250 rows x 9 columns]

# %% [markdown]
# ## Inner Joins I
# - Inner joins merge two tables based on *shared*/*common* values in columns.
# - If only one **DataFrame** has a value, pandas will exclude it from the final results set.
# - If the same ID occurs multiple times, pandas will store each possible combination of the values.
# - The design of the join ensures that the results will be the same no matter what **DataFrame** the `merge` method is invoked upon.
# <img src="SQL_Joins.png" width="800" height="800"/>

# %%
#Find the customers that came on both weeks
week1.merge(week2, how="inner", on="Customer ID", suffixes=[" - Week 1", " - Week 2"])
# Out:
#     Customer ID  Food ID - Week 1  Food ID - Week 2
# 0           537                 9                 5
# 1           155                 9                 3
# 2           155                 1                 3
# 3           503                 5                 8
# 4           503                 5                 9
# ..          ...               ...               ...
# 57          945                 5                 4
# 58          343                 3                 5
# 59          343                 3                 2
# 60          343                 3                 7
# 61          621                 9                 6
#
# [62 rows x 3 columns]

# %% [markdown]
# ## Inner Joins II
# - We can pass multiple arguments to the `on` parameter of the `merge` method. Pandas will require matches in both columns across the **DataFrames**.

# %%
#Find the customers who came in both weeks and ordered the same food item both weeks

# %%
week1.merge(week2, how="inner", on=["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
is_21wk1 = week1["Customer ID"] == 21
is_21wk2 = week2["Customer ID"] == 21
week1[is_21wk1]
# Out:
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
week2[is_21wk2] #this customer came in twice on the first week and once on the second
# week and ordered the same thing every time, hence why there are two records in the 
# inner join DF
# Out:
#     Customer ID  Food ID
# 30           21        4

# %% [markdown]
# ## Full/Outer Join
# - A **full/outer** joins values that are found in either **DataFrame** or both **DataFrames**.
# - Pandas does not mind if a value exists in one **DataFrame** but not the other.
# - If a value does not exist in one **DataFrame**, it will have a `NaN`.
#
# <img src="SQL_Joins.png" width="800" height="800"/>

# %%
week1.merge(week2, how="outer", on="Customer ID", suffixes=[" Week 1", " Week 2" ])
week1.merge(week2, how="outer", on="Customer ID", suffixes=[" Week 1", " Week 2" ], indicator=True)
# Out:
#      Customer ID  Food ID Week 1  Food ID Week 2      _merge
# 0            537             9.0             5.0        both
# 1             97             4.0             NaN   left_only
# 2            658             1.0             NaN   left_only
# 3            202             2.0             NaN   left_only
# 4            155             9.0             3.0        both
# ..           ...             ...             ...         ...
# 449          855             NaN             4.0  right_only
# 450          559             NaN            10.0  right_only
# 451          276             NaN             4.0  right_only
# 452          556             NaN            10.0  right_only
# 453          252             NaN             9.0  right_only
#
# [454 rows x 4 columns]

# %%
merged = week1.merge(week2, how="outer", on="Customer ID", suffixes=[" Week 1", " Week 2" ], indicator=True)
merged
# Out:
#      Customer ID  Food ID Week 1  Food ID Week 2      _merge
# 0            537             9.0             5.0        both
# 1             97             4.0             NaN   left_only
# 2            658             1.0             NaN   left_only
# 3            202             2.0             NaN   left_only
# 4            155             9.0             3.0        both
# ..           ...             ...             ...         ...
# 449          855             NaN             4.0  right_only
# 450          559             NaN            10.0  right_only
# 451          276             NaN             4.0  right_only
# 452          556             NaN            10.0  right_only
# 453          252             NaN             9.0  right_only
#
# [454 rows x 4 columns]

# %%
merged["_merge"].value_counts()
# Out:
# _merge
# right_only    197
# left_only     195
# both           62
# Name: count, dtype: int64

# %%
# ONLY EXIST IN ONE TABLE
only_one = merged["_merge"].isin(["left_only", "right_only"])
merged[only_one]
# Out:
#      Customer ID  Food ID Week 1  Food ID Week 2      _merge
# 1             97             4.0             NaN   left_only
# 2            658             1.0             NaN   left_only
# 3            202             2.0             NaN   left_only
# 6            213             8.0             NaN   left_only
# 7            600             1.0             NaN   left_only
# ..           ...             ...             ...         ...
# 449          855             NaN             4.0  right_only
# 450          559             NaN            10.0  right_only
# 451          276             NaN             4.0  right_only
# 452          556             NaN            10.0  right_only
# 453          252             NaN             9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# ## Merging by Indexes with the left_index and right_index Parameters
# - Use the `on` parameter if the column(s) to be matched on have the same names in both **DataFrames**.
# - Use the `left_on` and `right_on` parameters if the column(s) to be matched on have different names in the two **DataFrames**.
# - Use the `left_index` or `right_index` parameters (set to True) to if the values to be matched on are found in the index of a **DataFrame**.

# %%
customers = pd.read_csv("restaurant_customers.csv", index_col="ID")
foods = pd.read_csv("restaurant_foods.csv", index_col="Food ID")
week1 = pd.read_csv("restaurant_week_1_sales.csv")
week2 = pd.read_csv("restaurant_week_2_sales.csv")

# %%
week1.merge(customers, how="left", left_on="Customer ID", right_index=True)
# Out:
#      Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0            537        9     Cheryl   Carroll  Female   Zoombeat
# 1             97        4     Amanda   Watkins  Female        Ozu
# 2            658        1    Patrick      Webb    Male  Browsebug
# 3            202        2      Louis  Campbell    Male  Rhynoodle
# 4            155        9    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...        ...       ...     ...        ...
# 245          413        9      Diane    Bailey  Female    Wikibox
# 246          926        6       Anne    Wagner  Female      Skyba
# 247          134        3      Diana      Hall  Female      Quinu
# 248          396        6       Juan    Romero    Male    Zoonder
# 249          535       10      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# 3       Account Representative III
# 4       Database Administrator III
# ..                             ...
# 245               Technical Writer
# 246                Legal Assistant
# 247              Financial Advisor
# 248             Analyst Programmer
# 249             Research Associate
#
# [250 rows x 7 columns]

# %%
week1.merge(
    customers, how="left", left_on="Customer ID", right_index=True
).merge(foods, how="left", left_on="Food ID", right_index=True)
# Out:
#      Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0            537        9     Cheryl   Carroll  Female   Zoombeat
# 1             97        4     Amanda   Watkins  Female        Ozu
# 2            658        1    Patrick      Webb    Male  Browsebug
# 3            202        2      Louis  Campbell    Male  Rhynoodle
# 4            155        9    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...        ...       ...     ...        ...
# 245          413        9      Diane    Bailey  Female    Wikibox
# 246          926        6       Anne    Wagner  Female      Skyba
# 247          134        3      Diana      Hall  Female      Quinu
# 248          396        6       Juan    Romero    Male    Zoonder
# 249          535       10      Nancy       Cox  Female     Trudeo
#
#                         Occupation   Food Item  Price
# 0                 Registered Nurse       Donut   0.99
# 1              Account Coordinator  Quesadilla   4.25
# 2    Community Outreach Specialist       Sushi   3.99
# 3       Account Representative III     Burrito   9.99
# 4       Database Administrator III       Donut   0.99
# ..                             ...         ...    ...
# 245               Technical Writer       Donut   0.99
# 246                Legal Assistant       Pasta  13.99
# 247              Financial Advisor        Taco   2.99
# 248             Analyst Programmer       Pasta  13.99
# 249             Research Associate       Drink   1.75
#
# [250 rows x 9 columns]

# %% [markdown]
# ## The join Method
# - The `join` method is a shortcut for concatenating two **DataFrames** when merging by index labels.

# %%
customers = pd.read_csv("restaurant_customers.csv", index_col="ID")
foods = pd.read_csv("restaurant_foods.csv", index_col="Food ID")
week1 = pd.read_csv("restaurant_week_1_sales.csv")
week2 = pd.read_csv("restaurant_week_2_sales.csv")
times = pd.read_csv("restaurant_week_1_times.csv")
times.head()
# Out:
#   Time of Day
# 0    14:54:59
# 1    20:55:17
# 2    01:16:22
# 3    16:17:26
# 4    19:26:11

# %%
week1.merge(times, how="left", left_index=True, right_index=True)
# is the same as
week1.join(times)
# Out:
#      Customer ID  Food ID Time of Day
# 0            537        9    14:54:59
# 1             97        4    20:55:17
# 2            658        1    01:16:22
# 3            202        2    16:17:26
# 4            155        9    19:26:11
# ..           ...      ...         ...
# 245          413        9    04:44:14
# 246          926        6    07:46:21
# 247          134        3    20:45:08
# 248          396        6    01:09:06
# 249          535       10    18:18:50
#
# [250 rows x 3 columns]
